# %%
import pandas as pd

df = pd.read_csv('../data/relatorio.csv')

display(df)
# Out:
#    numero_recibo        data   cliente   valor
# 0              3  10/01/2026   Roberto   260.0
# 1              4  10/01/2026   Antonio    80.0
# 2              5  13/01/2026       Ery   150.0
# 3              6  13/01/2026     Micon   180.0
# 4              7  13/01/2026   Michael   180.0
# 5              8  13/01/2026   Michael   550.0
# 6              9  13/01/2026   Eduardo  1600.0
# 7             10  14/01/2026  Benedito    80.0
# 8             11  15/01/2026     Almir   500.0
